# %%
from PIL import Image
import numpy as np

img = Image.open('images/laoqi.png')
img_arr = np.array(img)
img_arr.shape

# %%
gray_img = img.convert("L")
gray_img_arr = np.array(gray_img)
gray_img_arr.shape

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('images/laoqi.png', 0)
plt.imshow(img, cmap='gray', interpolation='bicubic')
plt.xticks([]),plt.yticks([])

# %%
from PIL import Image
import cv2

img = cv2.imread('images/laoqi.png', 0)
Image.fromarray(img)

# %%
img_part = img[50:260, 100:280]
Image.fromarray(img_part)
img_reverse = 255-img
Image.fromarray(img_reverse)

# %%
import numpy as np
from PIL import Image
import cv2

i1 = cv2.imread('images/laoqi.png', -1)
i2 = cv2.imread('images/book.png', -1)
p1 = i1[50:260, 100:280]
p2 = i2[300:, 100:280]
i3 = np.vstack([p1, p2])
Image.fromarray(i3)
# Out:
# <PIL.Image.Image image mode=RGBA size=180x615 at 0x7F90D2EF1130>
